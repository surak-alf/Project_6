# %%
from telethon import TelegramClient
from telethon.tl.functions.channels import GetMessagesRequest
from telethon.tl.types import InputChannel, InputPeerChannel
import asyncio
import os
import nest_asyncio

# %%
# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@nevacomputer'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=10  # Fetch the latest 10 messages

        )

        # Extract message content
        for message in messages:  # Iterate through the messages list
            print(message.message)


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 46514
# Invalid code. Please try again.
# Please enter the code you received: 46544
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
# None
#
#
#
# Very portable and can do multi-task
#
# #HP ELITEBOOK 1040 G6
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : HP ELITEBOOK
# ✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 14” convertable touch screen full HD
# ✨🅒︎🅟︎🅤︎: CORE I7 8th generation
# ✨🅡︎🅐︎🅜︎:16 GB 𝗗𝗗𝗥4
# ✨🅢︎🅣︎🅞︎🅡︎🅐︎🅖︎: 512 GB SSD
# ✨🅖︎raphics: intel uhd graphics
# ✨🅞︎🅢︎:window 11 pro
# ✨🅑︎🅐︎🅣︎🅣︎🅔︎🅡︎🅨︎: 5HR
# ✨🅢︎🅣︎🅐︎🅣︎🅤︎🅢︎:  open box
# Price  👇
# 📩@rasneva ለአጭር መልእክት
#  ይደዉሉ ☎️
# 🏢 አድራሻ: - መገናኛ ማራቶን የ ገበያ ማእከል በ ዋናው መግቢያ መሬት ላይ
# ወይንም ግራውንድ ፍሎር ብቅ ይበሉ
#  👉ነቫ ኮምፒውተር👈 መሆኑን ያረጋግጡ
#
# ድህረ ገጻችንን ይጎብኙ
# www.nevacomputer.com
#
# ቴሌግራም ቻናላችንን ይቀላቀሉ
#
# https://t.me/nevacomputer
#
# Very portable and can do multi-task
#
# #HP
# 🅑︎🅡︎🅐︎🅝︎🅓︎ : HP ELITEBOOK
# ...

# %%
# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@ethio_brand_collection'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=10  # Fetch the latest 10 messages

        )

        # Extract message content
        for message in messages:  # Iterate through the messages list
            print(message.message)


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 27944
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
# Nike air zoom pegasus running
# Size 40,41,42,43
# Price 3400 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     EthioBrand ✅
# Adidas terrex running
# size 41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     EthioBrand ✅
# Skechers Quantum flex
# size 40,41,42,43
# Price 3500 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
#                                     EthioBrand ✅
# Nike Air Force olive canvas
# size 40,41,42,43
# Price 3600 birr
# 📌አድራሻ-ሜክሲኮ ኮሜርስ ጀርባ መዚድ ፕላዛ የመጀመሪያ ደረጃ እንደወጡ 101 የቢሮ ቁጥር ያገኙናል or call 0920238243
# ...

# %%
# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@Leyueqa'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=30  # Fetch the latest 30 messages

        )

        # Extract message content
        for message in messages:  # Iterate through the messages list
            print(message.message)


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 76310
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
#
# 👍👍👍👍
#
# 📣 Kitchen Expert 3 in 1 Chopper and Garlic Peeler
#
# ✔️ 3 ሊትር የሚይዙ ሁለት ቋቶች
# ✔️ አንዱ የብረት አንዱ ደግሞ ወፍራም ጠርሙስ
# ✔️ ባለ 4 ምላጭ እና ባለ 2 ምላጭ መፍጪያ ያለው
# 👀 ስጋ፣ ጨጓራ፣ አትክልት፣ ቀይ ሽንኩርት፣ነጭ ሽንኩርት ይፈጩበታል👀
# 🔔 የደረቀ እና የተፈለፈለ ነጭ ሽንኩርት ገለባ  መላጪያ ያለው🔔
# 📌 ተጨማሪ አንድ መቀየሪያ ባለ 4 ምላጭ ያለው
# ✔️ባለ 3 ፕሬስ መፍጪያ
#
# ዋጋ 👍3700
#
# ከነፃ ዲሊቨሪ ጋር
# #ክፍያዎን_በሞባይል_ባንኪንግ_መፈፀምም_ይችላሉ በተጨማሪ #ከ_1000_ብር በላይ የሆኑ #ሁለት_ዕቃዎች ሲገዙ ስጦታ እንልክለዎታለን
# 🎁 T.me/Leyueqa 👈ቻናላችንን ለጓደኛዎ ሸር ማድረግዎን አይርሱ
#             0911236983 @Leyustore
#             0944109295 @Lemaze_z
#             0946242424 @Le_Mazez
#
#
#
# 🔥🔥🔥2 ድስቶች + 1 ወጥ ማቅረቢያ + 1 መጥበሻ
#   የማይዙ የማያሳርሩ ለይታ ውቡ የሆኑ
#          ዋጋ 💵6500 ብር  🛞🛞ከነፃ ዲሊቨሪ ጋር🛞🛞
#
#      0911236983 @Leyustore
#             0944109295 @Lemaze_z
# ...

# %%
# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@modernshoppingcenter'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=30  # Fetch the latest 30 messages

        )

        # Extract message content
        for message in messages:  # Iterate through the messages list
            print(message.message)


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 41525
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
#
#
#
# ቴሌግራም🫐 t.me/modernshoppingcenter
#      "በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን"
#
#     🔠🔠🔠🔠  🔠🔠🔠🔠
#
#   🔠🔠🔠🔠🔠🔠🔠🔠🔠
#
# 🔤 የልጆች ምግብ መስሪያ
# 🔤 በከፍተኛ ሙቀት ምግብን እስቲም የሚያደርግ
# 🔤 እስቲም ያደረገውን የሚደባልቅ ወይም የሚፈጭ
# 🔤 ምላጩ እስቴለስ እስቲል የሆነ
# 🔤 ጆጉ 500ml የመያዝ አቅም ያለው
# 🔤 mixing power 110W
# 🔤 Heating power 300W
# 🔤 ለማፅዳት ቀላል
# 🔤 ለአጠቃቀም ምቹ
#
#                   በ📥
#                 💵💵
#
# ☃️ የቲክ ቶክ ፔጃችንን ለማግኘት ሊንኩን ይጫኑ ⬇️
# http://tiktok.com/@modernshoppingcenter1
#
# 📞 0924743736
# 📞 0974978584
#
# በስራችን ላይ ቅሬታ ካለዎት ብቻ በዚህ ስልክ ደዉለዉ ያሳዉቁን። 🔽
#                       📞  0961373839
#
# ✈️ የመረጡትን እቃ ለማዘዝ ከታች ባለዉ የቴሌግራም አድራሻ ይላኩልን
#
# 💬 t.me/modernshopping1
# 💬 t.me/modernshopping2
#
# 🏍🏍አዲስ አበባ ዉስጥ ከ100ብር እስከ 200ብር ብቻ በማስከፈል ያሉበት ድረስ በፈጣን ሞተረኞቻችን እንልክልዏታለን።
#
# ...

# %%
# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@qnashcom'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=30  # Fetch the latest 30 messages

        )

        # Extract message content
        for message in messages:  # Iterate through the messages list
            print(message.message)


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 33349
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
# ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER
#
# ⚡️🔼Kemei የፀጉር ማስተካከያ
#
# 💯 ከፍተኛ ጥራት
#
# ✂️የራስ ፀጉር እና ፂምን በስርአት እና በጥራት ለማስተካከል አስተማማኝ ማሽን
# ✂️በሚፈልጉት መጠን ለመቁረጥ መቀያየሪ ቁጥሮች ያሉት
# ✂️በቻርጅ የሚሰራ አስተማምኝ ባትሪ
#
# ✂️High quality material
# ✂️Professional Hair Clippers
# ✂️Adjustable Taper Lever
# ✂️chargeable and strong battery
#
# 📣 ለማዘዝ = @Orderqnash
#
# 💵 2600 ብር ብቻ
#
# ✔️ ስለ ዕቃወቹ መረጃ እና ቪዲዮዎች ለማየት ቴሌግራማንን ይቀላቀሉ
# Telegram - t.me/qnashcom
#
# ውስን ፍሬ ነው የቀረው ❌
# Limited Stock ‼️
#         📌  ይፍጠኑ
#
# Telegram - t.me/qnashcom
# 🔼ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# ...

# %%
import re

# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@qnashcom'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=30  # Fetch the latest 30 messages

        )

        # Extract message content
        for message in messages:  # Iterate through the messages list
            print(message.message)


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())

def preprocess_amharic_text(text):
    """
    Preprocesses Amharic text by tokenizing, normalizing, and handling specific linguistic features.

    Args:
        text: The input Amharic text string.

    Returns:
        A list of preprocessed tokens.
    """

    # 1. Lowercase the text
    text = text.lower()

    # 2. Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)

    # 3. Handle Amharic-specific issues:
    #    - Consider handling ge'ez characters and their variations
    #    - Address issues with script switching (e.g., Latin characters mixed with Amharic)
    #    (This might require more advanced techniques and potentially custom rules)

    # 4. Tokenize the text (split into individual words)
    tokens = text.split()

    # 5. Normalize tokens (optional):
    #    - Stemming: Reduce words to their root form (e.g., "ይበል" -> "በል")
    #    - Lemmatization: Reduce words to their dictionary form (more accurate than stemming)
    #    (You might need to use a custom Amharic stemmer or lemmatizer)

    return tokens

# ... (In your main loop) ...

for message in messages.messages:
    amharic_text = message.message  # Assuming the message is in Amharic
    preprocessed_tokens = preprocess_amharic_text(amharic_text)
    print(preprocessed_tokens)
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 70169
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
# ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER
#
# ⚡️🔼Kemei የፀጉር ማስተካከያ
#
# 💯 ከፍተኛ ጥራት
#
# ✂️የራስ ፀጉር እና ፂምን በስርአት እና በጥራት ለማስተካከል አስተማማኝ ማሽን
# ✂️በሚፈልጉት መጠን ለመቁረጥ መቀያየሪ ቁጥሮች ያሉት
# ✂️በቻርጅ የሚሰራ አስተማምኝ ባትሪ
#
# ✂️High quality material
# ✂️Professional Hair Clippers
# ✂️Adjustable Taper Lever
# ✂️chargeable and strong battery
#
# 📣 ለማዘዝ = @Orderqnash
#
# 💵 2600 ብር ብቻ
#
# ✔️ ስለ ዕቃወቹ መረጃ እና ቪዲዮዎች ለማየት ቴሌግራማንን ይቀላቀሉ
# Telegram - t.me/qnashcom
#
# ውስን ፍሬ ነው የቀረው ❌
# Limited Stock ‼️
#         📌  ይፍጠኑ
#
# Telegram - t.me/qnashcom
# 🔼ጥራት ✔️ ዋስትና 🛍 ቅናሽ
#
# 🏬 አድራሻ ፦
# ቁጥር 1 :- መገናኛ ዘፍመሽ ግራንድ ሞል 3 ተኛ ፎቅ ቁጥር 329
#
# ቁጥር 2 :- ጀሞ 1 ከለላ ህንፃ ግራውንድ ለይ G07
#
# ❌❌ ማሳሰብያ: ሱቃችን ሲመጡ ትክክለኛ የኛ ሱቅ መሆኑ ያረጋግጡ  የራሳችን ሎጎ መኖሩን እና 329 / G07 መሆኑ ያረጋግጡ !
#
# ስልክ:
# 📱0946966440
# 📱0992606060
# ...

# %%
import re
from telethon import TelegramClient
from telethon.tl.functions.channels import GetMessagesRequest
from telethon.tl.types import InputChannel, InputPeerChannel
import asyncio
import os
import nest_asyncio

# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@qnashcom'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=30  # Fetch the latest 30 messages

        )

        # Extract message content
        # This loop is now inside the main function
        for message in messages:
            amharic_text = message.message  # Assuming the message is in Amharic
            preprocessed_tokens = preprocess_amharic_text(amharic_text)
            print(preprocessed_tokens)


def preprocess_amharic_text(text):
    """
    Preprocesses Amharic text by tokenizing, normalizing, and handling specific linguistic features.

    Args:
        text: The input Amharic text string.

    Returns:
        A list of preprocessed tokens.
    """

    # 1. Lowercase the text
    text = text.lower()

    # 2. Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)

    # 3. Handle Amharic-specific issues:
    #    - Consider handling ge'ez characters and their variations
    #    - Address issues with script switching (e.g., Latin characters mixed with Amharic)
    #    (This might require more advanced techniques and potentially custom rules)

    # 4. Tokenize the text (split into individual words)
    tokens = text.split()

    # 5. Normalize tokens (optional):
    #    - Stemming: Reduce words to their root form (e.g., "ይበል" -> "በል")
    #    - Lemmatization: Reduce words to their dictionary form (more accurate than stemming)
    #    (You might need to use a custom Amharic stemmer or lemmatizer)

    return tokens


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 99559
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
# ...

# %%
import re
from telethon import TelegramClient
from telethon.tl.functions.channels import GetMessagesRequest
from telethon.tl.types import InputChannel, InputPeerChannel
import asyncio
import os
import nest_asyncio

# API ID and hash
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# the channel username or hash
channel_username = '@qnashcom'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)

# Create a TelegramClient instance
client = TelegramClient(session_file, api_id, api_hash)


async def main():
    # Resolve the channel entity
    async with client:  # Use async with inside the main function
        channel = await client.get_entity(channel_username)

        # InputChannel for GetMessagesRequest
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        # Get the latest messages (adjust limit as needed)
        # Use client.get_messages instead of client(GetMessagesRequest(...)) or client.invoke
        messages = await client.get_messages(
            entity=input_peer, # Pass the channel entity as the entity argument
            limit=30  # Fetch the latest 30 messages

        )

        # Extract message content
        # This loop is now inside the main function
        for message in messages:
            amharic_text = message.message  # Assuming the message is in Amharic
            # Check if amharic_text is not None before processing
            if amharic_text is not None:
                preprocessed_tokens = preprocess_amharic_text(amharic_text)
                print(preprocessed_tokens)


def preprocess_amharic_text(text):
    """
    Preprocesses Amharic text by tokenizing, normalizing, and handling specific linguistic features.

    Args:
        text: The input Amharic text string.

    Returns:
        A list of preprocessed tokens.
    """

    # 1. Lowercase the text
    text = text.lower()

    # 2. Remove punctuation and special characters
    text = re.sub(r'[^\w\s]', '', text)

    # 3. Handle Amharic-specific issues:
    #    - Consider handling ge'ez characters and their variations
    #    - Address issues with script switching (e.g., Latin characters mixed with Amharic)
    #    (This might require more advanced techniques and potentially custom rules)

    # 4. Tokenize the text (split into individual words)
    tokens = text.split()

    # 5. Normalize tokens (optional):
    #    - Stemming: Reduce words to their root form (e.g., "ይበል" -> "በል")
    #    - Lemmatization: Reduce words to their dictionary form (more accurate than stemming)
    #    (You might need to use a custom Amharic stemmer or lemmatizer)

    return tokens


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 91647
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
# ...

# %%
import pandas as pd
import asyncio
from telethon import TelegramClient
from telethon.tl.functions.channels import GetMessagesRequest
from telethon.tl.types import InputChannel, InputPeerChannel

# API ID and hash (replace with your credentials)
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)


async def get_messages_from_channel(client, channel_username):
    """
    Fetches messages from a specific Telegram channel.

    Args:
        client: The Telegram client instance.
        channel_username: The username or hash of the channel.

    Returns:
        A list of messages from the channel.
    """

    async with client:
        channel = await client.get_entity(channel_username)
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        messages = await client.get_messages(
            entity=input_peer,
            limit=30  # Fetch the latest 30 messages (adjust as needed)
        )

        return messages


async def main():
    # Create a Telegram client instance
    client = TelegramClient(session_file, api_id, api_hash)

    # Define the channel usernames
    channel_usernames = [
        '@qnashcom',  # Replace with your channel usernames
        '@modernshoppingcenter',
        '@Shewabrand',
        '@Leyueqa',
        '@nevacomputer',
    ]

    # Create an empty list to store all messages
    all_messages = []

    # Loop through each channel and fetch messages
    for channel_username in channel_usernames:
        messages = await get_messages_from_channel(client, channel_username)
        all_messages.extend(messages)  # Add messages to the list

    # Create a DataFrame to store the messages
    data = []
    for message in all_messages:
        data.append({
            "channel_username": channel_username,  # Add channel name
            "message_text": message.message
        })

    df = pd.DataFrame(data)

    # Print or save the DataFrame
    print(df)
    df.to_csv('collected_messages.csv', index=False)  # Save to CSV (optional)

    # Return the DataFrame
    return df


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    asyncio.run(main())
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 62845
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
#     channel_username                                       message_text
# 0      @nevacomputer  ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 1      @nevacomputer  ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 2      @nevacomputer  ➡️🟢Manual Vegetable Cutter Slicer Kitchen Roll...
# 3      @nevacomputer  📣🔼 Foldable Height Adjustable Metal Frame Lapt...
# 4      @nevacomputer  📣🔼 Foldable Height Adjustable Metal Frame Lapt...
# ..               ...                                                ...
# 145    @nevacomputer
# 146    @nevacomputer
# 147    @nevacomputer
# 148    @nevacomputer
# 149    @nevacomputer  🅑︎🅡︎🅐︎🅝︎🅓︎ : DELL G15 \n✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 15.6”...
#
# [150 rows x 2 columns]

# %%
import pandas as pd
import asyncio
from telethon import TelegramClient
from telethon.tl.functions.channels import GetMessagesRequest
from telethon.tl.types import InputChannel, InputPeerChannel
import nest_asyncio
import os


# API ID and hash (replace with your credentials)
api_id = 25986002
api_hash = '903d9d999f9a489212bbcd24075581d6'

# Define session file path
session_file = 'session_name.session'

# Delete the session file if it exists
if os.path.exists(session_file):
    os.remove(session_file)


async def get_messages_from_channel(client, channel_username):
    """
    Fetches messages from a specific Telegram channel.

    Args:
        client: The Telegram client instance.
        channel_username: The username or hash of the channel.

    Returns:
        A list of messages from the channel.
    """

    async with client:
        channel = await client.get_entity(channel_username)
        input_channel = InputChannel(channel.id, channel.access_hash)
        input_peer = InputPeerChannel(channel.id, channel.access_hash)

        messages = await client.get_messages(
            entity=input_peer,
            limit=30  # Fetch the latest 30 messages (adjust as needed)
        )

        return messages


async def main():
    # Create a Telegram client instance
    client = TelegramClient(session_file, api_id, api_hash)

    # Define the channel usernames
    channel_usernames = [
        '@qnashcom',  # Replace with your channel usernames
        '@modernshoppingcenter',
        '@Shewabrand',
        '@Leyueqa',
        '@nevacomputer',
    ]

    # Create an empty list to store all messages
    all_messages = []

    # Loop through each channel and fetch messages
    for channel_username in channel_usernames:
        messages = await get_messages_from_channel(client, channel_username)
        all_messages.extend(messages)  # Add messages to the list

    # Create a DataFrame to store the messages
    data = []
    for message in all_messages:
        data.append({
            "channel_username": channel_username,  # Add channel name
            "message_text": message.message
        })

    df = pd.DataFrame(data)

    # Print or save the DataFrame
    print(df)
    df.to_csv('collected_messages.csv', index=False)  # Save to CSV (optional)

    # Return the DataFrame
    return df  # This line is added to return the DataFrame


if __name__ == '__main__':
    # Apply nest_asyncio patch to allow nested event loops
    nest_asyncio.apply()
    # Execute the main function in the existing event loop
    df = asyncio.run(main()) # Assign the return value of asyncio.run(main()) to df
# Out:
# Please enter your phone (or bot token): +251911761714
# Please enter the code you received: 56684
# Please enter your password: ··········
# Signed in successfully as Sura Ke; remember to not break the ToS or you will risk an account ban!
#     channel_username                                       message_text
# 0      @nevacomputer  🔥🔥 Saachi Touch Stove Ceramic Cooker\n\n📣 ባለ አ...
# 1      @nevacomputer  ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 2      @nevacomputer  ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 3      @nevacomputer  ➡️🟢Manual Vegetable Cutter Slicer Kitchen Roll...
# 4      @nevacomputer  📣🔼 Foldable Height Adjustable Metal Frame Lapt...
# ..               ...                                                ...
# 145    @nevacomputer
# 146    @nevacomputer
# 147    @nevacomputer
# 148    @nevacomputer
# 149    @nevacomputer  🅑︎🅡︎🅐︎🅝︎🅓︎ : DELL G15 \n✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 15.6”...
#
# [150 rows x 2 columns]

# %%
df
# Out:
#     channel_username                                       message_text
# 0      @nevacomputer  🔥🔥 Saachi Touch Stove Ceramic Cooker\n\n📣 ባለ አ...
# 1      @nevacomputer  ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 2      @nevacomputer  ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 3      @nevacomputer  ➡️🟢Manual Vegetable Cutter Slicer Kitchen Roll...
# 4      @nevacomputer  📣🔼 Foldable Height Adjustable Metal Frame Lapt...
# ..               ...                                                ...
# 145    @nevacomputer
# 146    @nevacomputer
# 147    @nevacomputer
# 148    @nevacomputer
# 149    @nevacomputer  🅑︎🅡︎🅐︎🅝︎🅓︎ : DELL G15 \n✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 15.6”...
#
# [150 rows x 2 columns]

# %%
message_df=df['message_text']
message_df
# Out:
# 0      🔥🔥 Saachi Touch Stove Ceramic Cooker\n\n📣 ባለ አ...
# 1      ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 2      ⚡️➡️KEMEI PROFESSIONAL HAIR CLIPPER\n\n⚡️🔼Keme...
# 3      ➡️🟢Manual Vegetable Cutter Slicer Kitchen Roll...
# 4      📣🔼 Foldable Height Adjustable Metal Frame Lapt...
#                              ...
# 145
# 146
# 147
# 148
# 149    🅑︎🅡︎🅐︎🅝︎🅓︎ : DELL G15 \n✨🅓︎🅘︎🅢︎🅟︎🅛︎🅐︎🅨︎: 15.6”...
# Name: message_text, Length: 150, dtype: object

# %%
import re
# Define a function to remove emojis
def remove_emojis(text):
    emoji_pattern = re.compile(
        "["
        "\U0001F600-\U0001F64F"  # emoticons
        "\U0001F300-\U0001F5FF"  # symbols & pictographs
        "\U0001F680-\U0001F6FF"  # transport & map symbols
        "\U0001F700-\U0001F77F"  # alchemical symbols
        "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
        "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
        "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
        "\U0001FA00-\U0001FA6F"  # Chess Symbols
        "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
        "\U00002702-\U000027B0"  # Dingbats
        "\U000024C2-\U0001F251"
        "]+",
        flags=re.UNICODE
    )
    return emoji_pattern.sub(r'', text)

# Apply the function to the 'Message' column
df['message_text'] = df['message_text'].apply(remove_emojis)

# Display the updated DataFrame
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-a326e142e17c> in <cell line: 0>()
#      21
#      22 # Apply the function to the 'Message' column
# ---> 23 df['message_text'] = df['message_text'].apply(remove_emojis)
#      24
#      25 # Display the updated DataFrame
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
# ...

# %%
import re
# Define a function to remove emojis
def remove_emojis(text):
    if text is not None:  # Check if text is not None
        emoji_pattern = re.compile(
            "["
            "\U0001F600-\U0001F64F"  # emoticons
            "\U0001F300-\U0001F5FF"  # symbols & pictographs
            "\U0001F680-\U0001F6FF"  # transport & map symbols
            "\U0001F700-\U0001F77F"  # alchemical symbols
            "\U0001F780-\U0001F7FF"  # Geometric Shapes Extended
            "\U0001F800-\U0001F8FF"  # Supplemental Arrows-C
            "\U0001F900-\U0001F9FF"  # Supplemental Symbols and Pictographs
            "\U0001FA00-\U0001FA6F"  # Chess Symbols
            "\U0001FA70-\U0001FAFF"  # Symbols and Pictographs Extended-A
            "\U00002702-\U000027B0"  # Dingbats
            "\U000024C2-\U0001F251"
            "]+",
            flags=re.UNICODE
        )
        return emoji_pattern.sub(r'', text)
    else:
        return None  # Return None if text is None

# Apply the function to the 'message_text' column
df['message_text'] = df['message_text'].apply(remove_emojis)

# Display the updated DataFrame
print(df.head())
# Out:
#   channel_username                                       message_text
# 0    @nevacomputer   Saachi Touch Stove Ceramic Cooker\n\n ባለ አንድ ...
# 1    @nevacomputer  KEMEI PROFESSIONAL HAIR CLIPPER\n\nKemei የፀጉር ...
# 2    @nevacomputer  KEMEI PROFESSIONAL HAIR CLIPPER\n\nKemei የፀጉር ...
# 3    @nevacomputer  Manual Vegetable Cutter Slicer Kitchen Roller ...
# 4    @nevacomputer   Foldable Height Adjustable Metal Frame Laptop...

# %%
message_text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-7e7217009b03> in <cell line: 0>()
# ----> 1 message_text
#
# NameError: name 'message_text' is not defined
